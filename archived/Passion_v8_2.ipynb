# %% [markdown]
# # Welcome to Passion!
# Passion is a model that can detection anomaly using different methods (Both supervised and unsupervised) <br>
#
# 1. The goal for this project is to study the difference between different anomnaly detection model, and to   <br>
#  find the state of art method for detecting anomaly in real world data<br>
# 2. Evaluate the results based on this :real server data+ https://www.kaggle.com/sohier/30-years-of-european-wind-generation (Unsupervised)+ https://github.com/numenta/NAB (Unsupervised+Supervised)  https://www.cs.ucr.edu/~eamonn/time_series_data/ (Supervised) <br>
# 3. Also use real data generated from server.
# 4. The model has the following fuctions: <br>
#     a. Visualize the input data. Help the user to find critical features within the inputs. <br>
#     b. Give user options to choose different models that are suitable for different circumstances. <br>
#     c. Evaluate the performance based on the rules in this link https://github.com/numenta/NAB <br>
#     d. Save model. Easy to be appplied to other dataset. <br>
#
# 5. Add un-labeled and labeled data

# %% [markdown]
# # What's new in version 8.2
#
# 1. Add Wavenet for un-supervised mode

# %%
# import packages 


from matplotlib.pylab import rc
import torch
from scipy.stats import chisquare
from scipy.stats import pearsonr 
import pickle
import pandas as pd
import datetime
import matplotlib
import tensorflow as tf
import sklearn
import math
import matplotlib.pyplot as plt
import xgboost
from xgboost import XGBClassifier
from xgboost import plot_importance
import numpy as np
from sklearn.model_selection import train_test_split 
import sklearn
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder 
import copy
import scipy
import datetime
import time
import os
from sklearn.model_selection import KFold 
from sklearn.metrics import roc_curve 
from sklearn.metrics import roc_auc_score
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.covariance import EllipticEnvelope
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
import gc
import json
plot_path = "plots/"

# %%
# Real server data

root_path = "Data/Ant_202007/"


cif = pd.read_json(root_path+'cif.json', orient='index')
paycore = pd.read_json(root_path+'paycore.json', orient='index')
paydecision = pd.read_json(root_path+'paydecision.json', orient='index')
paydecision2 = pd.read_json(root_path+'paydecision2.json', orient='index')
paydecision3 = pd.read_json(root_path+'paydecision3.json', orient='index')

df = pd.DataFrame()
df["time_stamp"] = cif.index
df["cif"] = cif[0].values
df["paycore"] = paycore[0].values
df["paydecision"] = paydecision[0].values
df["paydecision2"] = paydecision2[0].values
df["paydecision3"] = paydecision3[0].values

# Optional
if False:
    df.to_csv(root_path+"fusion.csv")

    
# convert time stamp
df['time_stamp'] = pd.to_datetime(df['time_stamp'])
names_array = np.array(df.keys()[1:],dtype="str")
os.listdir(root_path)
# Out:
# ['.ipynb_checkpoints',
#  'cif.json',
#  'fusion.csv',
#  'paycore.json',
#  'paydecision.json',
#  'paydecision2.json',
#  'paydecision3.json']

# %%
if False:
    
    # calculate previous hour high low:
    # convert to seconds
    temp = df['time_stamp'] - min(df['time_stamp'])
    temp = temp.dt.total_seconds().astype(int)
    df["hours"] = temp//3600

    h_max = max(df["hours"])+1

    for n in range(len(names_array)):
        df[names_array[n]+"_open"] = df[names_array[n]]
        df[names_array[n]+"_close"] = df[names_array[n]]
        df[names_array[n]+"_max"] = df[names_array[n]]
        df[names_array[n]+"_min"] = df[names_array[n]]

    for j in range(1,h_max):
        mask_j = df["hours"]==j-1
        max_val = df[mask_j][names_array].max(axis=0).values
        min_val = df[mask_j][names_array].max(axis=0).values
        open_val = df[mask_j][names_array].values[0,:]
        close_val = df[mask_j][names_array].values[-1,:]
        mask_i = df["hours"]==j
        r = df[mask_i][names_array].shape[0]
        df.loc[mask_i,[r+"_open" for r in names_array]] = np.tile(open_val,(r,1))
        df.loc[mask_i,[r+"_close" for r in names_array]] = np.tile(close_val,(r,1))

        df.loc[mask_i,[r+"_max" for r in names_array]] = np.tile(max_val,(r,1))
        df.loc[mask_i,[r+"_min" for r in names_array]] = np.tile(min_val,(r,1))

# %%
root_path = 'Data/Stocks/'
#root_path = "/kaggle/input/price-volume-data-for-all-us-stocks-etfs/ETFs/"

stock = pd.read_csv(root_path + "googl.us.txt")
df = stock

# %%
import matplotlib
from matplotlib.pylab import rc
font = {'family': 'normal','weight': 'bold',
        'size': 25}

matplotlib.rc('font', **font)
rc('axes', linewidth=3)


plt.subplot(1,1,1)
plt.plot(df["Open"],"k",label="Open")
plt.plot(df["Close"],"r",label="Close")


plt.xlabel("Day")
plt.ylabel(r"${\rm value}$")
plt.suptitle("Stock price vs Day Google")

fig = matplotlib.pyplot.gcf()

fig.set_size_inches(20,10)
plt.legend(fontsize=25,handlelength=5,ncol=3)
plt.show()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
# Let's check whether there is a peroid in week/month?
import datetime
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['weekday'] = df['Date'].dt.weekday
df['monthday'] = df['Date'].dt.day
df['month'] = df['Date'].dt.month

from matplotlib.pylab import rc
font = {'family': 'normal','weight': 'bold',
        'size': 25}

matplotlib.rc('font', **font)
rc('axes', linewidth=3)

color_array = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

plt.subplot(1,1,1)


names_array = list(df.keys()[1:5])
for i in range(len(names_array)):
    #print("Doing %d"%i)
    plt.plot(df.groupby('weekday').mean().index+1,df.groupby('weekday').mean()[names_array[i]],color_array[i],label=names_array[i],linewidth=2,markersize=5)
    




plt.xlabel("Day")
plt.ylabel(r"${\rm value}$")
plt.suptitle("Mean Usage grouped by weekday")

fig = matplotlib.pyplot.gcf()

fig.set_size_inches(20,10)
plt.legend()
plt.show()

# %%
from matplotlib.pylab import rc
font = {'family': 'normal','weight': 'bold',
        'size': 25}

matplotlib.rc('font', **font)
rc('axes', linewidth=3)

color_array = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

plt.subplot(1,1,1)


names_array = list(df.keys()[1:5])
for i in range(len(names_array)):
    #print("Doing %d"%i)
    plt.plot(df.groupby('monthday').mean().index+1,df.groupby('monthday').mean()[names_array[i]],color_array[i],label=names_array[i],linewidth=2,markersize=5)
    




plt.xlabel("Day")
plt.ylabel(r"${\rm value}$")
plt.suptitle("Mean Usage grouped by monthday")

fig = matplotlib.pyplot.gcf()

fig.set_size_inches(20,10)
plt.legend()
plt.show()

# %%
# By month?


from matplotlib.pylab import rc
font = {'family': 'normal','weight': 'bold',
        'size': 25}

matplotlib.rc('font', **font)
rc('axes', linewidth=3)

color_array = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

plt.subplot(1,1,1)


names_array = list(df.keys()[1:5])
for i in range(len(names_array)):
    #print("Doing %d"%i)
    plt.plot(df.groupby('month').mean().index+1,df.groupby('month').mean()[names_array[i]],color_array[i],label=names_array[i],linewidth=2,markersize=5)
    




plt.xlabel("month")
plt.ylabel(r"${\rm value}$")
plt.suptitle("Mean Usage grouped by month")

fig = matplotlib.pyplot.gcf()

fig.set_size_inches(20,10)
plt.legend()
plt.show()

# %% [markdown]
# # baseline model: GRU+Dense layer structure:

# %%
from sklearn import preprocessing
from keras.models import Model
from sklearn.preprocessing import LabelEncoder 
import tensorflow as tf
from keras.layers import Input,Masking,Dense,GRU
from sklearn.model_selection import train_test_split 
from keras.layers import Dropout
# some hyper parameters
# Here we use 30 day data to predict future stock price. May need to modify later
delta_t = 30
n_cell = 50
dropout_rate= 0.1
n_epoch=30
batch=256

# %%
checkpoint_path = "model/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

min_max_scaler = preprocessing.StandardScaler()

# min-max scaler
np_scaled = min_max_scaler.fit_transform(df[names_array])

df_scaled = pd.DataFrame(np_scaled,columns=names_array)


X = np.zeros((df_scaled.shape[0]-delta_t,delta_t,len(names_array)),dtype=float)
y = df_scaled["Close"][delta_t:]

  
for i in range(len(y)):
    if i%800==0:
        print("Prepare data %.2f percent"%(100*i/len(y)))
    X[i,:,:] = df_scaled[i:i+delta_t][names_array].values

# split train test:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)
# Out:
# Prepare data 0.00 percent
# Prepare data 24.22 percent
# Prepare data 48.44 percent
# Prepare data 72.66 percent
# Prepare data 96.88 percent

# %%
def generate_model(MAX_TIMESTEPS,MAX_NB_VARIABLES):
    ip = Input(shape=(MAX_TIMESTEPS,MAX_NB_VARIABLES))
    # split into x and y two channels

    x = Masking()(ip)
    x = GRU(n_cell)(x)

    out = Dense(1)(x)
    #out = Dropout(dropout_rate)(x)
    #loc, scale = tf.keras.layers.GaussianNoise(stddev=0.01)(out)
    
    # now we only output loc
    #out=loc

    model = Model(ip, out)
    model.summary()

    # add load model code here to fine-tune

    return model

model = generate_model(delta_t,X.shape[2])
model.compile(loss='mae', optimizer='adam')
#model.summary()

callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# Train
history = model.fit(X_train, y_train, epochs=n_epoch, batch_size=batch, validation_data=(X_test, y_test),callbacks=[callback], verbose=2, shuffle=False)

# Test:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=False)
y_pre = model.predict(X_test)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 30, 4)]           0
# _________________________________________________________________
# masking_1 (Masking)          (None, 30, 4)             0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 50)                8400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 8,451
# Trainable params: 8,451
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
#
# Epoch 00001: saving model to model/cp.ckpt
# 10/10 - 1s - loss: 0.4632 - val_loss: 0.1508
# Epoch 2/30
#
# Epoch 00002: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.1457 - val_loss: 0.0643
# Epoch 3/30
#
# Epoch 00003: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0810 - val_loss: 0.0595
# Epoch 4/30
#
# Epoch 00004: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0593 - val_loss: 0.0555
# Epoch 5/30
#
# Epoch 00005: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0554 - val_loss: 0.0499
# Epoch 6/30
#
# Epoch 00006: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0459 - val_loss: 0.0437
# Epoch 7/30
#
# Epoch 00007: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0411 - val_loss: 0.0404
# Epoch 8/30
#
# Epoch 00008: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0369 - val_loss: 0.0348
# Epoch 9/30
#
# Epoch 00009: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0324 - val_loss: 0.0305
# Epoch 10/30
#
# Epoch 00010: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0292 - val_loss: 0.0275
# Epoch 11/30
#
# Epoch 00011: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0270 - val_loss: 0.0287
# Epoch 12/30
#
# Epoch 00012: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0270 - val_loss: 0.0309
# Epoch 13/30
#
# Epoch 00013: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0273 - val_loss: 0.0292
# Epoch 14/30
#
# Epoch 00014: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0262 - val_loss: 0.0254
# Epoch 15/30
#
# Epoch 00015: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0248 - val_loss: 0.0239
# Epoch 16/30
#
# Epoch 00016: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0240 - val_loss: 0.0240
# Epoch 17/30
#
# Epoch 00017: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0241 - val_loss: 0.0236
# Epoch 18/30
#
# Epoch 00018: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0238 - val_loss: 0.0235
# Epoch 19/30
#
# Epoch 00019: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0237 - val_loss: 0.0235
# Epoch 20/30
#
# Epoch 00020: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0235 - val_loss: 0.0231
# Epoch 21/30
#
# Epoch 00021: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0234 - val_loss: 0.0231
# Epoch 22/30
#
# Epoch 00022: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0233 - val_loss: 0.0229
# Epoch 23/30
#
# Epoch 00023: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0230 - val_loss: 0.0227
# Epoch 24/30
#
# Epoch 00024: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0229 - val_loss: 0.0226
# Epoch 25/30
#
# Epoch 00025: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0229 - val_loss: 0.0224
# Epoch 26/30
#
# Epoch 00026: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0226 - val_loss: 0.0224
# Epoch 27/30
#
# Epoch 00027: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0227 - val_loss: 0.0221
# Epoch 28/30
#
# Epoch 00028: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0224 - val_loss: 0.0222
# Epoch 29/30
#
# Epoch 00029: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0224 - val_loss: 0.0220
# Epoch 30/30
#
# Epoch 00030: saving model to model/cp.ckpt
# 10/10 - 0s - loss: 0.0224 - val_loss: 0.0221

# %%
from matplotlib.pylab import rc
font = {'family': 'normal','weight': 'bold',
        'size': 25}

matplotlib.rc('font', **font)
rc('axes', linewidth=3)

color_array = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

plt.subplot(1,1,1)

min_val = np.nanmin(df["Close"])
max_val = np.nanmax(df["Close"])



date_array = np.arange(0,len(y_test),1)

y1 = min_val+(max_val-min_val)*y_test
y2 = min_val+(max_val-min_val)*y_pre[:,0]
plt.plot(date_array,y1,"k",label = "Data")
plt.plot(date_array,y2,"r",label = "Prediction")
plt.plot(date_array,y1-y2,"b",label = "Difference")
plt.xlabel("Day")
plt.ylabel(r"${\rm value}$")
plt.suptitle("Stock price prediction MAE=%.4f"%np.nanmean(abs(y1-y2)))

fig = matplotlib.pyplot.gcf()

fig.set_size_inches(20,10)
plt.legend()
plt.show()

# %% [markdown]
# # Well GRU is a very basic toy model, then we will use WaveNet which is designed for this kind of problem
# Thanks for DeepMind: https://www.deepmind.com/blog/article/wavenet-generative-model-raw-audio

# %%
from keras.models import Model
from keras.layers import Input, Conv1D, Dense, Activation, Dropout, Lambda, Multiply, Add, Concatenate
from keras.optimizers import Adam

# %%
# hyper-parameters
n_filters = 32
filter_width = 2
dilation_rates = [2**i for i in range(7)] * 2

# %%
# define an input history series and pass it through a stack of dilated causal convolution blocks
history_seq = Input(shape=(None, 1))
x = history_seq

skips = []
for dilation_rate in dilation_rates:
    
    # preprocessing - equivalent to time-distributed dense
    x = Conv1D(16, 1, padding='same', activation='relu')(x) 
    
    # filter
    x_f = Conv1D(filters=n_filters,
                 kernel_size=filter_width, 
                 padding='causal',
                 dilation_rate=dilation_rate)(x)
    
    # gate
    x_g = Conv1D(filters=n_filters,
                 kernel_size=filter_width, 
                 padding='causal',
                 dilation_rate=dilation_rate)(x)
    
    # combine filter and gating branches
    z = Multiply()([Activation('tanh')(x_f),
                    Activation('sigmoid')(x_g)])
    
    # postprocessing - equivalent to time-distributed dense
    z = Conv1D(16, 1, padding='same', activation='relu')(z)
    
    # residual connection
    x = Add()([x, z])    
    
    # collect skip connections
    skips.append(z)

# add all skip connection outputs 
out = Activation('relu')(Add()(skips))

# final time-distributed dense layers 
out = Conv1D(128, 1, padding='same')(out)
out = Activation('relu')(out)
out = Dropout(.2)(out)
out = Conv1D(1, 1, padding='same')(out)

# extract training target at end
def slice(x, seq_length):
    return x[:,-seq_length:,:]

pred_seq_train = Lambda(slice, arguments={'seq_length':66})(out)

model = Model(history_seq, pred_seq_train)
model.compile(Adam(), loss='mean_absolute_error')

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, None, 1)]    0
# __________________________________________________________________________________________________
# conv1d_116 (Conv1D)             (None, None, 16)     32          input_7[0][0]
# __________________________________________________________________________________________________
# conv1d_117 (Conv1D)             (None, None, 32)     1056        conv1d_116[0][0]
# __________________________________________________________________________________________________
# conv1d_118 (Conv1D)             (None, None, 32)     1056        conv1d_116[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, 32)     0           conv1d_117[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, 32)     0           conv1d_118[0][0]
# __________________________________________________________________________________________________
# multiply_28 (Multiply)          (None, None, 32)     0           activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# conv1d_119 (Conv1D)             (None, None, 16)     528         multiply_28[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, None, 16)     0           conv1d_116[0][0]
#                                                                  conv1d_119[0][0]
# __________________________________________________________________________________________________
# conv1d_120 (Conv1D)             (None, None, 16)     272         add_30[0][0]
# __________________________________________________________________________________________________
# conv1d_121 (Conv1D)             (None, None, 32)     1056        conv1d_120[0][0]
# __________________________________________________________________________________________________
# conv1d_122 (Conv1D)             (None, None, 32)     1056        conv1d_120[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, 32)     0           conv1d_121[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, 32)     0           conv1d_122[0][0]
# __________________________________________________________________________________________________
# multiply_29 (Multiply)          (None, None, 32)     0           activation_62[0][0]
#                                                                  activation_63[0][0]
# __________________________________________________________________________________________________
# conv1d_123 (Conv1D)             (None, None, 16)     528         multiply_29[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, None, 16)     0           conv1d_120[0][0]
#                                                                  conv1d_123[0][0]
# __________________________________________________________________________________________________
# conv1d_124 (Conv1D)             (None, None, 16)     272         add_31[0][0]
# __________________________________________________________________________________________________
# conv1d_125 (Conv1D)             (None, None, 32)     1056        conv1d_124[0][0]
# __________________________________________________________________________________________________
# conv1d_126 (Conv1D)             (None, None, 32)     1056        conv1d_124[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, 32)     0           conv1d_125[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, 32)     0           conv1d_126[0][0]
# __________________________________________________________________________________________________
# multiply_30 (Multiply)          (None, None, 32)     0           activation_64[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# conv1d_127 (Conv1D)             (None, None, 16)     528         multiply_30[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, None, 16)     0           conv1d_124[0][0]
#                                                                  conv1d_127[0][0]
# __________________________________________________________________________________________________
# conv1d_128 (Conv1D)             (None, None, 16)     272         add_32[0][0]
# __________________________________________________________________________________________________
# conv1d_129 (Conv1D)             (None, None, 32)     1056        conv1d_128[0][0]
# __________________________________________________________________________________________________
# conv1d_130 (Conv1D)             (None, None, 32)     1056        conv1d_128[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, 32)     0           conv1d_129[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, 32)     0           conv1d_130[0][0]
# __________________________________________________________________________________________________
# multiply_31 (Multiply)          (None, None, 32)     0           activation_66[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# conv1d_131 (Conv1D)             (None, None, 16)     528         multiply_31[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, None, 16)     0           conv1d_128[0][0]
#                                                                  conv1d_131[0][0]
# __________________________________________________________________________________________________
# conv1d_132 (Conv1D)             (None, None, 16)     272         add_33[0][0]
# __________________________________________________________________________________________________
# conv1d_133 (Conv1D)             (None, None, 32)     1056        conv1d_132[0][0]
# __________________________________________________________________________________________________
# conv1d_134 (Conv1D)             (None, None, 32)     1056        conv1d_132[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, 32)     0           conv1d_133[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, 32)     0           conv1d_134[0][0]
# __________________________________________________________________________________________________
# multiply_32 (Multiply)          (None, None, 32)     0           activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# conv1d_135 (Conv1D)             (None, None, 16)     528         multiply_32[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, None, 16)     0           conv1d_132[0][0]
#                                                                  conv1d_135[0][0]
# __________________________________________________________________________________________________
# conv1d_136 (Conv1D)             (None, None, 16)     272         add_34[0][0]
# __________________________________________________________________________________________________
# conv1d_137 (Conv1D)             (None, None, 32)     1056        conv1d_136[0][0]
# __________________________________________________________________________________________________
# conv1d_138 (Conv1D)             (None, None, 32)     1056        conv1d_136[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, 32)     0           conv1d_137[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, 32)     0           conv1d_138[0][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, None, 32)     0           activation_70[0][0]
#                                                                  activation_71[0][0]
# __________________________________________________________________________________________________
# conv1d_139 (Conv1D)             (None, None, 16)     528         multiply_33[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, None, 16)     0           conv1d_136[0][0]
#                                                                  conv1d_139[0][0]
# __________________________________________________________________________________________________
# conv1d_140 (Conv1D)             (None, None, 16)     272         add_35[0][0]
# __________________________________________________________________________________________________
# conv1d_141 (Conv1D)             (None, None, 32)     1056        conv1d_140[0][0]
# __________________________________________________________________________________________________
# conv1d_142 (Conv1D)             (None, None, 32)     1056        conv1d_140[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, 32)     0           conv1d_141[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, 32)     0           conv1d_142[0][0]
# __________________________________________________________________________________________________
# multiply_34 (Multiply)          (None, None, 32)     0           activation_72[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# conv1d_143 (Conv1D)             (None, None, 16)     528         multiply_34[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, None, 16)     0           conv1d_140[0][0]
#                                                                  conv1d_143[0][0]
# __________________________________________________________________________________________________
# conv1d_144 (Conv1D)             (None, None, 16)     272         add_36[0][0]
# __________________________________________________________________________________________________
# conv1d_145 (Conv1D)             (None, None, 32)     1056        conv1d_144[0][0]
# __________________________________________________________________________________________________
# conv1d_146 (Conv1D)             (None, None, 32)     1056        conv1d_144[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, 32)     0           conv1d_145[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, 32)     0           conv1d_146[0][0]
# __________________________________________________________________________________________________
# multiply_35 (Multiply)          (None, None, 32)     0           activation_74[0][0]
#                                                                  activation_75[0][0]
# __________________________________________________________________________________________________
# conv1d_147 (Conv1D)             (None, None, 16)     528         multiply_35[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, None, 16)     0           conv1d_144[0][0]
#                                                                  conv1d_147[0][0]
# __________________________________________________________________________________________________
# conv1d_148 (Conv1D)             (None, None, 16)     272         add_37[0][0]
# __________________________________________________________________________________________________
# conv1d_149 (Conv1D)             (None, None, 32)     1056        conv1d_148[0][0]
# __________________________________________________________________________________________________
# conv1d_150 (Conv1D)             (None, None, 32)     1056        conv1d_148[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, 32)     0           conv1d_149[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, 32)     0           conv1d_150[0][0]
# __________________________________________________________________________________________________
# multiply_36 (Multiply)          (None, None, 32)     0           activation_76[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# conv1d_151 (Conv1D)             (None, None, 16)     528         multiply_36[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, None, 16)     0           conv1d_148[0][0]
#                                                                  conv1d_151[0][0]
# __________________________________________________________________________________________________
# conv1d_152 (Conv1D)             (None, None, 16)     272         add_38[0][0]
# __________________________________________________________________________________________________
# conv1d_153 (Conv1D)             (None, None, 32)     1056        conv1d_152[0][0]
# __________________________________________________________________________________________________
# conv1d_154 (Conv1D)             (None, None, 32)     1056        conv1d_152[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, 32)     0           conv1d_153[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, 32)     0           conv1d_154[0][0]
# __________________________________________________________________________________________________
# multiply_37 (Multiply)          (None, None, 32)     0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# conv1d_155 (Conv1D)             (None, None, 16)     528         multiply_37[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, None, 16)     0           conv1d_152[0][0]
#                                                                  conv1d_155[0][0]
# __________________________________________________________________________________________________
# conv1d_156 (Conv1D)             (None, None, 16)     272         add_39[0][0]
# __________________________________________________________________________________________________
# conv1d_157 (Conv1D)             (None, None, 32)     1056        conv1d_156[0][0]
# __________________________________________________________________________________________________
# conv1d_158 (Conv1D)             (None, None, 32)     1056        conv1d_156[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, 32)     0           conv1d_157[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, 32)     0           conv1d_158[0][0]
# __________________________________________________________________________________________________
# multiply_38 (Multiply)          (None, None, 32)     0           activation_80[0][0]
#                                                                  activation_81[0][0]
# __________________________________________________________________________________________________
# conv1d_159 (Conv1D)             (None, None, 16)     528         multiply_38[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, None, 16)     0           conv1d_156[0][0]
#                                                                  conv1d_159[0][0]
# __________________________________________________________________________________________________
# conv1d_160 (Conv1D)             (None, None, 16)     272         add_40[0][0]
# __________________________________________________________________________________________________
# conv1d_161 (Conv1D)             (None, None, 32)     1056        conv1d_160[0][0]
# __________________________________________________________________________________________________
# conv1d_162 (Conv1D)             (None, None, 32)     1056        conv1d_160[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, 32)     0           conv1d_161[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, 32)     0           conv1d_162[0][0]
# __________________________________________________________________________________________________
# multiply_39 (Multiply)          (None, None, 32)     0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# conv1d_163 (Conv1D)             (None, None, 16)     528         multiply_39[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, None, 16)     0           conv1d_160[0][0]
#                                                                  conv1d_163[0][0]
# __________________________________________________________________________________________________
# conv1d_164 (Conv1D)             (None, None, 16)     272         add_41[0][0]
# __________________________________________________________________________________________________
# conv1d_165 (Conv1D)             (None, None, 32)     1056        conv1d_164[0][0]
# __________________________________________________________________________________________________
# conv1d_166 (Conv1D)             (None, None, 32)     1056        conv1d_164[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, 32)     0           conv1d_165[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, 32)     0           conv1d_166[0][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, None, 32)     0           activation_84[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# conv1d_167 (Conv1D)             (None, None, 16)     528         multiply_40[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, None, 16)     0           conv1d_164[0][0]
#                                                                  conv1d_167[0][0]
# __________________________________________________________________________________________________
# conv1d_168 (Conv1D)             (None, None, 16)     272         add_42[0][0]
# __________________________________________________________________________________________________
# conv1d_169 (Conv1D)             (None, None, 32)     1056        conv1d_168[0][0]
# __________________________________________________________________________________________________
# conv1d_170 (Conv1D)             (None, None, 32)     1056        conv1d_168[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, 32)     0           conv1d_169[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, 32)     0           conv1d_170[0][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, None, 32)     0           activation_86[0][0]
#                                                                  activation_87[0][0]
# __________________________________________________________________________________________________
# conv1d_171 (Conv1D)             (None, None, 16)     528         multiply_41[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, None, 16)     0           conv1d_119[0][0]
#                                                                  conv1d_123[0][0]
#                                                                  conv1d_127[0][0]
#                                                                  conv1d_131[0][0]
#                                                                  conv1d_135[0][0]
#                                                                  conv1d_139[0][0]
#                                                                  conv1d_143[0][0]
#                                                                  conv1d_147[0][0]
#                                                                  conv1d_151[0][0]
#                                                                  conv1d_155[0][0]
#                                                                  conv1d_159[0][0]
#                                                                  conv1d_163[0][0]
#                                                                  conv1d_167[0][0]
#                                                                  conv1d_171[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, 16)     0           add_44[0][0]
# __________________________________________________________________________________________________
# conv1d_172 (Conv1D)             (None, None, 128)    2176        activation_88[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, 128)    0           conv1d_172[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, None, 128)    0           activation_89[0][0]
# __________________________________________________________________________________________________
# conv1d_173 (Conv1D)             (None, None, 1)      129         dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, None, 1)      0           conv1d_173[0][0]
# ==================================================================================================
# Total params: 42,833
# Trainable params: 42,833
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
df = pd.read_csv(root_path + "googl.us.txt")

# %%
# min-max scaler
np_scaled = min_max_scaler.fit_transform(df[names_array])

df_scaled = pd.DataFrame(np_scaled,columns=names_array)


X = np.zeros((df_scaled.shape[0]-delta_t,delta_t,len(names_array)),dtype=float)
y = df_scaled[names_array][delta_t:]

  
for i in range(len(y)):
    if i%800==0:
        print("Prepare data %.2f percent"%(100*i/len(y)))
    X[i,:,:] = df_scaled[i:i+delta_t][names_array].values

# split train test:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)
# Out:
# Prepare data 0.00 percent
# Prepare data 24.22 percent
# Prepare data 48.44 percent
# Prepare data 72.66 percent
# Prepare data 96.88 percent

# %%
# Sanity check
# Here the input is delta_t = 30
# We can specify the output Let's say it's output_t=5
# Here we only predict the close price, you can add dimension if you want
delta_t = 30
output_t=5

# %%
batch_size = 8
data_in = X_train[:batch_size,:,:]
data_in.shape
# Out:
# (8, 30, 4)

# %%
data_out = np.zeros((batch_size,output_t,data_in.shape[-1]))
for i in range(output_t):
        
    # record next time step prediction (last time step of model output) 
    last_step_pred = []
    for j in range(data_in.shape[-1]):
        last_step_pred.append(model(data_in[:,:,j])[:,-1,0])
    last_step_pred = np.array(last_step_pred)
    last_step_pred = last_step_pred.T
    data_out[:,i,:] = last_step_pred
    last_step_pred = np.expand_dims(last_step_pred, axis=1)
    
        
    # add the next time step prediction to the history sequence
    data_in = np.concatenate((data_in,last_step_pred),axis=1)
data_out.shape
# Out:
# (8, 5, 4)

# %%
## To boost the performance, I willset output_t=1 :)

# %%
# Use MSE:

loss_object = tf.keras.losses.MeanSquaredError()


def loss_function(real, pred):
    
    loss_ = loss_object(real, pred)

    #mask = tf.cast(mask, dtype=loss_.dtype)
    #loss_ *= mask
  
    return tf.reduce_sum(loss_)
train_MSE = tf.keras.metrics.MeanSquaredError(name='train_MSE')
# here we only predict delta_t = 1
print(loss_function(y_train.iloc[:batch_size,:], data_out[:,0,:]))
# Out:
# tf.Tensor(1.097499132156372, shape=(), dtype=float64)

# %%
import os


train_step_signature = [
        tf.TensorSpec(shape=(None, None), dtype=tf.int64),
        tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    ]

@tf.function(input_signature=train_step_signature)

def train_step(inp, tar):
    print(inp.shape,tar.shape)

    with tf.GradientTape() as tape:
        
        data_in = inp

        data_out = np.zeros((batch_size,output_t,data_in.shape[-1]))
        for i in range(output_t):

            # record next time step prediction (last time step of model output) 
            last_step_pred = []
            for j in range(data_in.shape[-1]):
                last_step_pred.append(model(data_in[:,:,j])[:,-1,0])
            last_step_pred = np.array(last_step_pred)
            last_step_pred = last_step_pred.T
            data_out[:,i,:] = last_step_pred
            last_step_pred = np.expand_dims(last_step_pred, axis=1)


            # add the next time step prediction to the history sequence
            data_in = np.concatenate((data_in,last_step_pred),axis=1)

        loss = loss_function(tar, data_out)

        # Or we can only use MSE loss.
        
    gradients = tape.gradient(loss, model.trainable_variables)    
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    train_loss(loss)

# %%
lo = train_step(X_train[:batch_size,:,:],y_train.iloc[:batch_size,:])
